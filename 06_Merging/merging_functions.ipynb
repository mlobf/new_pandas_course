# %%
import pandas as pd
import numpy as np


df_aus = pd.read_csv('aus.csv')
df_bris = pd.read_csv('brisbane.csv')
df_usa = pd.read_csv('usa.csv', parse_dates=['date'], dayfirst=True)



df_usa
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_9191/3851437998.py in <module>
# ----> 1 import pandas as pd
#       2 import numpy as np
#       3
#       4
#       5 df_aus = pd.read_csv('aus.csv')
#
# ModuleNotFoundError: No module named 'pandas'

# %%
df_usa = pd.read_csv('usa.csv')
df_usa
# Out:
#          date  temperature
# 0   1/03/2000        15.25
# 1   1/09/2000        15.77
# 2   1/03/2001        15.98
# 3   1/09/2001        16.55
# 4   1/03/2002        15.32
# 5   1/09/2002        15.50
# 6   1/03/2003        17.18
# 7   1/09/2003        16.46
# 8   1/03/2004        16.30
# 9   1/09/2004        16.33
# 10  1/03/2005        15.45
# 11  1/09/2005        16.38
# 12  1/03/2006        16.26
# 13  1/09/2006        16.34
# 14  1/03/2007        17.37
# 15  1/09/2007        15.53
# 16  1/03/2008        16.91
# 17  1/09/2008        16.56
# 18  1/03/2009        15.61
# 19  1/09/2009        15.97
# 20  1/03/2010        16.34
# 21  1/09/2010        16.36
# 22  1/03/2011        16.39
# 23  1/09/2011        15.81
# 24  1/03/2012        16.08
# 25  1/09/2012        17.30
# 26  1/03/2013        17.35
# 27  1/09/2013        16.05
# 28  1/03/2014        16.25
# 29  1/09/2014        17.90
# 30  1/03/2015        16.11
# 31  1/09/2015        17.80
# 32  1/03/2016        16.33
# ...
